# %%
import os
import sys
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_distances
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import (
    Input,
    Conv2D,
    MaxPooling2D,
    GlobalAveragePooling2D,
    Dense,
    Flatten,
    Dropout,
)
from tensorflow.keras.optimizers import Adam
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../src")))
from preprocessing import load_metadata, load_images

BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), "../data"))
train_df, test_df = load_metadata(BASE_DIR)
train_images = load_images(train_df)
test_images = load_images(test_df)

# Feature extractor
inp = Input(shape=(128, 128, 3))
x = Conv2D(32, (3, 3), activation="relu")(inp)
x = MaxPooling2D()(x)
x = Conv2D(64, (3, 3), activation="relu")(x)
x = MaxPooling2D()(x)
x = Conv2D(128, (3, 3), activation="relu")(x)
x = GlobalAveragePooling2D()(x)
feature_model = Model(inputs=inp, outputs=x)
train_features = feature_model.predict(train_images, verbose=1)
test_features = feature_model.predict(test_images, verbose=1)

# KMeans clustering
kmeans = KMeans(n_clusters=2, random_state=42)
test_clusters = kmeans.fit_predict(test_features)
soil_centroid = np.mean(train_features, axis=0, keepdims=True)
d0, d1 = (
    cosine_distances([kmeans.cluster_centers_[0]], soil_centroid)[0][0],
    cosine_distances([kmeans.cluster_centers_[1]], soil_centroid)[0][0],
)
soil_cluster = 0 if d0 < d1 else 1
pseudo_labels = np.array([1 if c == soil_cluster else 0 for c in test_clusters])

# CNN Classifier
classifier = Sequential(
    [
        Conv2D(32, (3, 3), activation="relu", input_shape=(128, 128, 3)),
        MaxPooling2D(),
        Conv2D(64, (3, 3), activation="relu"),
        MaxPooling2D(),
        Flatten(),
        Dense(64, activation="relu"),
        Dropout(0.3),
        Dense(1, activation="sigmoid"),
    ]
)
classifier.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])
classifier.fit(test_images, pseudo_labels, epochs=100, batch_size=32, verbose=1)

# Save model
model_path = os.path.join(BASE_DIR, "kmeans_cnn_model.h5")
classifier.save(model_path)
print(f"✅ Model saved at {model_path}")
# Out:
# Loading images: 100%|██████████| 1222/1222 [00:02<00:00, 416.95it/s]
# Loading images: 100%|██████████| 967/967 [00:00<00:00, 1983.12it/s]
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Epoch 1/100
# /Users/sagnikdey/Downloads/FINAL/VENV/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/sagnikdey/Downloads/FINAL/VENV/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/sagnikdey/Downloads/FINAL/VENV/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/sagnikdey/Downloads/FINAL/VENV/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.7594 - loss: 0.6201
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9415 - loss: 0.1381
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9270 - loss: 0.1806
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9764 - loss: 0.0666
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9541 - loss: 0.0905
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9872 - loss: 0.0384
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9805 - loss: 0.0708
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9692 - loss: 0.0761
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9883 - loss: 0.0439
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9886 - loss: 0.0252
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9953 - loss: 0.0155
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9791 - loss: 0.0492
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9640 - loss: 0.1011
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9840 - loss: 0.0459
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9921 - loss: 0.0292
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9913 - loss: 0.0264
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9946 - loss: 0.0194
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9986 - loss: 0.0054
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9916 - loss: 0.0430
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9865 - loss: 0.0315
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9995 - loss: 0.0055
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9997 - loss: 0.0037
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9983 - loss: 0.0084
# Epoch 25/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9929 - loss: 0.0099
# Epoch 26/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9979 - loss: 0.0096
# Epoch 27/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9975 - loss: 0.0041
# Epoch 28/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 29/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 1.0000 - loss: 8.6529e-04
# Epoch 30/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 8.2330e-04
# Epoch 31/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 8.4777e-04
# Epoch 32/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9980 - loss: 0.0086
# Epoch 33/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9750 - loss: 0.0516
# Epoch 34/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9944 - loss: 0.0271
# Epoch 35/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9990 - loss: 0.0043
# Epoch 36/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 37/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 38/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 39/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 40/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 41/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 1.0000 - loss: 7.2662e-04
# Epoch 42/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 5.1211e-04
# Epoch 43/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 1.0000 - loss: 5.7504e-04
# Epoch 44/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 1.0000 - loss: 5.2174e-04
# Epoch 45/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 9.7216e-04
# Epoch 46/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 3.5922e-04
# Epoch 47/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9993 - loss: 0.0013
# Epoch 48/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9991 - loss: 0.0027
# Epoch 49/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9834 - loss: 0.0880
# Epoch 50/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9934 - loss: 0.0145
# Epoch 51/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9994 - loss: 0.0047
# Epoch 52/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9970 - loss: 0.0079
# Epoch 53/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9961 - loss: 0.0065
# Epoch 54/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 1.0000 - loss: 8.5859e-04
# Epoch 55/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 56/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 7.1252e-04
# Epoch 57/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 8.4168e-04
# Epoch 58/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 9.5918e-04
# Epoch 59/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 2.5260e-04
# Epoch 60/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 4.0606e-04
# Epoch 61/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 1.0000 - loss: 3.8533e-04
# Epoch 62/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 1.3051e-04
# Epoch 63/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 1.0000 - loss: 3.6807e-04
# Epoch 64/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 1.8070e-04
# Epoch 65/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 2.3791e-04
# Epoch 66/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 1.0000 - loss: 2.3792e-04
# Epoch 67/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 9.4091e-05
# Epoch 68/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 1.0000 - loss: 1.4974e-04
# Epoch 69/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 7.0194e-05
# Epoch 70/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 2.2029e-04
# Epoch 71/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 1.2936e-04
# Epoch 72/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 1.4825e-04
# Epoch 73/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 1.8272e-04
# Epoch 74/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 1.0000 - loss: 4.5760e-05
# Epoch 75/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 7.4652e-05
# Epoch 76/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 4.4045e-05
# Epoch 77/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 6.1137e-04
# Epoch 78/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 1.5053e-04
# Epoch 79/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9999 - loss: 4.2889e-04
# Epoch 80/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9965 - loss: 0.0069
# Epoch 81/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9686 - loss: 0.1055
# Epoch 82/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9940 - loss: 0.0275
# Epoch 83/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9978 - loss: 0.0123
# Epoch 84/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9960 - loss: 0.0077
# Epoch 85/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 86/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9996 - loss: 0.0020
# Epoch 87/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 88/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9951 - loss: 0.0110
# Epoch 89/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9948 - loss: 0.0106
# Epoch 90/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9999 - loss: 0.0029
# Epoch 91/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9929 - loss: 0.0114
# Epoch 92/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9960 - loss: 0.0131
# Epoch 93/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9946 - loss: 0.0133
# Epoch 94/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9997 - loss: 0.0022
# Epoch 95/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 96/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 97/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 98/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 5.6489e-04
# Epoch 99/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 4.2431e-04
# Epoch 100/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 1.0000 - loss: 2.6779e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model saved at /Users/sagnikdey/Downloads/FINAL/challenge-2/data/kmeans_cnn_model.h5
